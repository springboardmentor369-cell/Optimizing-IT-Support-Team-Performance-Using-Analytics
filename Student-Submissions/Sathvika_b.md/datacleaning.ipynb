# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\baira\OneDrive\Desktop\Technical Support Dataset.csv")
df
# Out:
#          Status  Ticket ID Priority Source                     Topic  \
# 0        Closed       1012      Low  Email           Feature request
# 1   In progress       1013     High  Phone             Product setup
# 2      Resolved       1014      Low   Chat  Purchasing and invoicing
# 3        Closed       1015   Medium  Email     Pricing and licensing
# 4        Closed       1016      Low  Email             Product setup
# ..          ...        ...      ...    ...                       ...
# 95       Closed       1131      Low  Email             Product setup
# 96       Closed       1132      Low  Email     Pricing and licensing
# 97     Resolved       1133     High   Chat             Product setup
# 98       Closed       1134      Low   Chat             Product setup
# 99     Resolved       1135      Low  Phone                Bug report
#
#          Agent Group           Agent Name         Created time  \
# 0   1st line support      Kristos Westoll  2023-01-02 00:58:36
# ...

# %%
df = df.head(100)
df
# Out:
#          Status  Ticket ID Priority Source                     Topic  \
# 0        Closed       1012      Low  Email           Feature request
# 1   In progress       1013     High  Phone             Product setup
# 2      Resolved       1014      Low   Chat  Purchasing and invoicing
# 3        Closed       1015   Medium  Email     Pricing and licensing
# 4        Closed       1016      Low  Email             Product setup
# ..          ...        ...      ...    ...                       ...
# 95       Closed       1131      Low  Email             Product setup
# 96       Closed       1132      Low  Email     Pricing and licensing
# 97     Resolved       1133     High   Chat             Product setup
# 98       Closed       1134      Low   Chat             Product setup
# 99     Resolved       1135      Low  Phone                Bug report
#
#          Agent Group           Agent Name         Created time  \
# 0   1st line support      Kristos Westoll  2023-01-02 00:58:36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Status                          100 non-null    object
#  1   Ticket ID                       100 non-null    int64
#  2   Priority                        100 non-null    object
#  3   Source                          100 non-null    object
#  4   Topic                           100 non-null    object
#  5   Agent Group                     100 non-null    object
#  6   Agent Name                      100 non-null    object
#  7   Created time                    100 non-null    object
#  8   Expected SLA to resolve         100 non-null    object
#  9   Expected SLA to first response  100 non-null    object
#  10  First response time             100 non-null    object
#  11  SLA For first response          100 non-null    object
# ...

# %%
df = df.drop(columns=["Source"])
df = df.drop(columns=["First response time"])
df = df.drop(columns=["Expected SLA to resolve"])
df = df.drop(columns=["Expected SLA to first response"])
df = df.drop(columns=["SLA For Resolution"])
df = df.drop(columns=["Close time"])
df = df.drop(columns=["Survey results"])
df = df.drop(columns=["Latitude"])
df = df.drop(columns=["Longitude"])
df = df.drop(columns=["SLA For first response"])
df
# Out:
#          Status  Ticket ID Priority                     Topic  \
# 0        Closed       1012      Low           Feature request
# 1   In progress       1013     High             Product setup
# 2      Resolved       1014      Low  Purchasing and invoicing
# 3        Closed       1015   Medium     Pricing and licensing
# 4        Closed       1016      Low             Product setup
# ..          ...        ...      ...                       ...
# 95       Closed       1131      Low             Product setup
# 96       Closed       1132      Low     Pricing and licensing
# 97     Resolved       1133     High             Product setup
# 98       Closed       1134      Low             Product setup
# 99     Resolved       1135      Low                Bug report
#
#          Agent Group           Agent Name         Created time  \
# 0   1st line support      Kristos Westoll  2023-01-02 00:58:36
# 1   2nd line support   Adolpho Messingham  2023-01-02 07:27:25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Status              100 non-null    object
#  1   Ticket ID           100 non-null    int64
#  2   Priority            100 non-null    object
#  3   Topic               100 non-null    object
#  4   Agent Group         100 non-null    object
#  5   Agent Name          100 non-null    object
#  6   Created time        100 non-null    object
#  7   Resolution time     85 non-null     object
#  8   Agent interactions  100 non-null    float64
#  9   Product group       100 non-null    object
#  10  Support Level       100 non-null    object
#  11  Country             100 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 9.5+ KB

# %%
df= df[["Ticket ID","Agent Name","Topic","Priority","Country","Product group","Agent Group","Created time","Resolution time","Agent interactions","Support Level","Status"]]
df
# Out:
#     Ticket ID           Agent Name                     Topic Priority  \
# 0        1012      Kristos Westoll           Feature request      Low
# 1        1013   Adolpho Messingham             Product setup     High
# 2        1014      Bernard Beckley  Purchasing and invoicing      Low
# 3        1015  Connor Danielovitch     Pricing and licensing   Medium
# 4        1016      Kristos Westoll             Product setup      Low
# ..        ...                  ...                       ...      ...
# 95       1131        Sheela Cutten             Product setup      Low
# 96       1132        Sheela Cutten     Pricing and licensing      Low
# 97       1133      Bernard Beckley             Product setup     High
# 98       1134        Sheela Cutten             Product setup      Low
# 99       1135   Adolpho Messingham                Bug report      Low
#
#                 Country                     Product group       Agent Group  \
# ...

# %%
df["Ticket ID"] = range(1,len(df)+1)
df
# Out:
#     Ticket ID           Agent Name                     Topic Priority  \
# 0           1      Kristos Westoll           Feature request      Low
# 1           2   Adolpho Messingham             Product setup     High
# 2           3      Bernard Beckley  Purchasing and invoicing      Low
# 3           4  Connor Danielovitch     Pricing and licensing   Medium
# 4           5      Kristos Westoll             Product setup      Low
# ..        ...                  ...                       ...      ...
# 95         96        Sheela Cutten             Product setup      Low
# 96         97        Sheela Cutten     Pricing and licensing      Low
# 97         98      Bernard Beckley             Product setup     High
# 98         99        Sheela Cutten             Product setup      Low
# 99        100   Adolpho Messingham                Bug report      Low
#
#                 Country                     Product group       Agent Group  \
# ...
